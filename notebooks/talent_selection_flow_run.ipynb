# %%
import sys
sys.path.insert(0, "..")

from src.talent_selection_flow.flow import TalentSelectionFlow

# %%
flow = TalentSelectionFlow(verbose=False)

# %%
cv_example = """
# CURRICULUM VITAE: ALEX R. DEVELOPER

## CONTACT INFORMATION
+ Email: alex.dev@email.com
+ Location: Madrid, Spain
+ LinkedIn: linkedin.com/in/alexdev

---

## PROFESSIONAL SUMMARY
Highly analytical Software Engineer with 5+ years of experience in Python 
and AI orchestration. Expert in building multi-agent systems using CrewAI.

---

## EXPERIENCE
+ **Senior Backend Engineer** | TechFlow Solutions (2021 - Present)
  - Led the migration of legacy pipelines to a microservices architecture.
  - Implemented automated CV screening using LLM-based gap analysis.

+ **Junior Developer** | Startup Inc. (2018 - 2021)
  - Developed RESTful APIs using FastAPI and PostgreSQL.
  - Optimized database queries, reducing latency by 30%.

---

## TECHNICAL SKILLS
+ Languages: Python, JavaScript, SQL
+ Frameworks: CrewAI, LangChain, FastAPI, Django
+ Tools: Docker, Kubernetes, Git, OpenRouter API

---

## EDUCATION
+ B.S. in Computer Science | University of Technology
"""
job_example = "We are seeking a Senior Data Scientist to lead our LLM optimization team. Requirements include 4+ years of experience with PyTorch, LangChain, and vector databases. You will be responsible for fine-tuning models and improving retrieval-augmented generation (RAG) pipelines in a fast-paced startup environment."
other_example = "tot el camp és un clam, som la gent blaugrana"

# %%
# await kickoff_async for notebooks
response = await flow.kickoff_async(inputs={"raw_input": cv_example})
# Out:
# Flow started with ID: fed7c173-755f-41e5-a94f-7f117088f605
# ╭─────────────────────────────────────────────── 🌊 Flow Execution ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name:                                                                                                          │
# │  TalentSelectionFlow                                                                                            │
# │  ID:                                                                                                            │
# │  fed7c173-755f-41e5-a94f-7f117088f605                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 🌊 Flow Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Flow Started                                                                                                   │
# │  Name: TalentSelectionFlow                                                                                      │
# │  ID: fed7c173-755f-41e5-a94f-7f117088f605                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────── 🔄 Flow Method Running ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Method: classify_input                                                                                         │
# │  Status: Running                                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2026-02-16 14:56:51.749 | DEBUG    | src.talent_selection_flow.crews.classification_crew.guardrails:validate_classifier_output:10 - Guardrail input: 'cv'
# ╭────────────────────────────────────────── 💬 Human Feedback Required ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Provide feedback on the Final Result above.                                                                    │
# │                                                                                                                 │
# │  • If you are happy with the result, simply hit Enter without typing anything.                                  │
# │  • Otherwise, provide specific improvement requests.                                                            │
# │  • You can provide multiple rounds of feedback until satisfied.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2026-02-16 14:56:58.195 | DEBUG    | src.db_ingestion.metadata_extraction_crew.guardrails:validate_cvmetadata_schema:12 - Guardrail input:
# {"skills": "Python, JavaScript, SQL, CrewAI, LangChain, FastAPI, Django, Docker, Kubernetes, Git, OpenRouter API", "industries": "Technology, Software Development", "experience_level": "senior", "country": "ES", "summary": "Highly analytical Software Engineer with 5+ years of experience in Python and AI orchestration. Expert in building multi-agent systems using CrewAI.", "education_level": "bachelor", "languages": "unknown"}
# 2026-02-16 14:56:58.565 | INFO     | src.db_ingestion.chroma_client:query_to_collection:153 - Initiating vector search in collection 'jobs' (Top K: 3)
# 2026-02-16 14:57:03.025 | WARNING  | src.db_ingestion.chroma_client:query_to_collection:165 - No matches found for country 'ES'. Broadening search to all regions to ensure candidate visibility.
# 2026-02-16 14:57:03.350 | DEBUG    | src.db_ingestion.chroma_client:query_to_collection:175 - Final formatted results:
# {'4733': {'title': 'Devops', 'similarity': 0.8877, 'skills': 'Ubuntu, Debian, shell scripting, PHP, Python, Ruby, Perl, nginx, haproxy, MySQL, Redis, Mesos, Hadoop, Scribe, Zookeeper, Puppet, Capistrano, ltrace, iotop, systemtap, task prioritization, independent work', 'industries': 'Marketing and Advertising', 'experience_level': 'senior', 'summary': 'Design, build, deploy, and maintain systems that are serving hundreds of millions of queries every day, write scripts to monitor systems and automate tasks, troubleshoot issues across the entire stack, and document current and future configuration processes and policies.', 'country': 'EE'}, '9267': {'title': 'Software Engineer I-Junior Developer', 'similarity': 0.8684000000000001, 'skills': 'C#, .NET, JavaScript, object-oriented development, database management, scripting', 'industries': 'Computer Software', 'experience_level': 'entry', 'summary': "Join an established team and grow your development skills while providing valuable contributions to our client's higher education commercial software solutions and their customers.", 'country': 'US'}, '15515': {'title': 'Database Administrator & BI Developer', 'similarity': 0.8616, 'skills': 'SQL Server, T-SQL, stored procedures, functions, views, triggers, indexes, query tuning, SSIS, ETL, DTS, SSAS, relational databases, source control, VSS, CVS, TFS, index tuning, query optimization, database development, application development, enterprise information integration', 'industries': 'Telecommunications', 'experience_level': 'senior', 'summary': 'Responsible for the performance, integrity and security of a database, involved in the planning and development of the database as well as troubleshooting any issues on behalf of the users, and responsible for aggregating data from multiple sources in an efficient data warehouse and designing enterprise-level solutions for very large multidimensional databases.', 'country': 'EG'}}
# 2026-02-16 14:57:11.426 | DEBUG    | src.talent_selection_flow.crews.cv_to_job_crew.guardrails:validate_gapanalysisoutput_schema:11 - Guardrail input:
# {
#   "jobs": {
#     "4733": {
#       "matched_skills": [
#         "Python"
#       ],
#       "missing_must_have": [
#         "Ubuntu",
#         "Debian",
#         "shell scripting",
#         "PHP",
#         "Ruby",
#         "Perl",
#         "nginx",
#         "haproxy",
#         "MySQL",
#         "Redis",
#         "Mesos",
#         "Hadoop",
#         "Scribe",
#         "Zookeeper",
#         "Puppet",
#         "Capistrano",
#         "ltrace",
#         "iotop",
#         "systemtap",
#         "task prioritization",
#         "independent work"
#       ]
#     },
#     "9267": {
#       "matched_skills": [
#         "JavaScript"
#       ],
#       "missing_must_have": [
#         "C#",
#         ".NET",
#         "object-oriented development",
#         "database management",
#         "scripting"
#       ]
#     },
#     "15515": {
#       "matched_skills": [
#         "SQL"
#       ],
#       "missing_must_have": [
#         "SQL Server",
#         "T-SQL",
#         "stored procedures",
#         "functions",
#         "views",
#         "triggers",
#         "indexes",
#         "query tuning",
#         "SSIS",
#         "ETL",
#         "DTS",
#         "SSAS",
#         "relational databases",
#         "source control",
#         "VSS",
#         "CVS",
#         "TFS",
#         "index tuning",
#         "query optimization",
#         "database development",
#         "application development",
#         "enterprise information integration"
#       ]
#     }
#   }
# }
# ╭────────────────────────────────────────────── ✅ Flow Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Flow Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  TalentSelectionFlow                                                                                            │
# │  ID:                                                                                                            │
# │  fed7c173-755f-41e5-a94f-7f117088f605                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
