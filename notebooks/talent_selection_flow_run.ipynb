# %%
import sys
sys.path.insert(0, "..")

from src.talent_selection_flow.flow import TalentSelectionFlow

# %%
flow = TalentSelectionFlow(verbose=False)

# %%
cv_example = "Experienced Software Engineer with 5+ years in Python, specialized in building scalable AI agents and distributed systems using CrewAI and FastAPI. From Houston."
job_example = "We are seeking a Senior Data Scientist to lead our LLM optimization team. Requirements include 4+ years of experience with PyTorch, LangChain, and vector databases. You will be responsible for fine-tuning models and improving retrieval-augmented generation (RAG) pipelines in a fast-paced startup environment."
other_example = "tot el camp és un clam, som la gent blaugrana"

# %%
# await kickoff_async for notebooks
response = await flow.kickoff_async(inputs={"raw_input": cv_example})
# Out:
# Flow started with ID: 6a8f7ab5-5d16-46e3-984d-dc0dd7b64f08
# ╭─────────────────────────────────────────────── 🌊 Flow Execution ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name:                                                                                                          │
# │  TalentSelectionFlow                                                                                            │
# │  ID:                                                                                                            │
# │  6a8f7ab5-5d16-46e3-984d-dc0dd7b64f08                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 🌊 Flow Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Flow Started                                                                                                   │
# │  Name: TalentSelectionFlow                                                                                      │
# │  ID: 6a8f7ab5-5d16-46e3-984d-dc0dd7b64f08                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2026-02-16 12:29:32.745 | DEBUG    | src.talent_selection_flow.crews.classification_crew.guardrails:validate_classifier_output:10 - Guardrail input: 'cv'
# ╭────────────────────────────────────────── 💬 Human Feedback Required ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Provide feedback on the Final Result above.                                                                    │
# │                                                                                                                 │
# │  • If you are happy with the result, simply hit Enter without typing anything.                                  │
# │  • Otherwise, provide specific improvement requests.                                                            │
# │  • You can provide multiple rounds of feedback until satisfied.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 2026-02-16 12:29:41.366 | DEBUG    | src.db_ingestion.metadata_extraction_crew.guardrails:validate_cvmetadata_schema:12 - Guardrail input:
# {"skills": "Python, CrewAI, FastAPI", "industries": "Software Engineering, AI, Distributed Systems", "experience_level": "senior", "country": "US", "summary": "Experienced Software Engineer with 5+ years in Python, specialized in building scalable AI agents and distributed systems using CrewAI and FastAPI.", "education_level": "unknown", "languages": "unknown"}
# 2026-02-16 12:29:41.637 | INFO     | src.db_ingestion.chroma_client:query_to_collection:153 - Initiating vector search in collection 'jobs' (Top K: 3)
# 2026-02-16 12:29:45.541 | DEBUG    | src.db_ingestion.chroma_client:query_to_collection:175 - Final formatted results:
# {'16162': {'title': 'Senior Quality Assurance Engineer (remote/telecommute)', 'similarity': 0.8062, 'skills': 'manual and automated testing, test plans, bug tracking, problem solving, decision-making, software engineering fundamentals, unit testing, automated testing, white-box and black-box testing, agile development, Selenium, TestNG, rapid development cycles, Jira, Testrail, Jenkins/CI, Git, HTML5/CSS/JavaScript, Java, Continuous Integration/Continuous Delivery, SaaS, On-Premise Enterprise products, Windows, OSX, iOS, Android, oral and written communications', 'industries': 'Internet', 'experience_level': 'senior', 'summary': 'Participate in product development process and ensure optimum quality of application by planning, scheduling and executing manual and automated testing throughout the development cycle and during periodic releases.', 'country': 'US'}, '2417': {'title': 'Sr. Developer - Python/Java', 'similarity': 0.8038, 'skills': 'Python, Oracle, Teradata, Linux, Java, shell scripting, Integration, XML, XLST, WCF, SOAP, JSON, RESTful services, systems, application frameworks, database optimization, software development projects, product development, banking, trading, payment, financial applications, security, single sign on, device fingerprinting, multi factor authentication, adaptive authentication, SDLC methodologies, Agile, Rational Unified Process, deployment automation, code reviews, test driven development', 'industries': 'Banking', 'experience_level': 'senior', 'summary': 'Leading bank is seeking a Senior Software Engineer (Python/ Java) in San Ramon for a contract role. The client is seeking a senior software engineer contractor for the Shared Services team.', 'country': 'US'}, '9267': {'title': 'Software Engineer I-Junior Developer', 'similarity': 0.7984, 'skills': 'C#, .NET, JavaScript, object-oriented development, database management, scripting', 'industries': 'Computer Software', 'experience_level': 'entry', 'summary': "Join an established team and grow your development skills while providing valuable contributions to our client's higher education commercial software solutions and their customers.", 'country': 'US'}}
# 2026-02-16 12:29:58.143 | DEBUG    | src.talent_selection_flow.crews.cv_to_job_crew.guardrails:validate_gapanalysisoutput_schema:11 - Guardrail input:
# {
#   "jobs": {
#     "16162": {
#       "matched_skills": [],
#       "missing_must_have": ["manual and automated testing", "test plans", "bug tracking", "problem solving", "decision-making", "software engineering fundamentals", "unit testing", "automated testing", "white-box and black-box testing", "agile development", "Selenium", "TestNG", "rapid development cycles", "Jira", "Testrail", "Jenkins/CI", "Git", "HTML5/CSS/JavaScript", "Java", "Continuous Integration/Continuous Delivery", "SaaS", "On-Premise Enterprise products", "Windows", "OSX", "iOS", "Android", "oral and written communications"],
#       "missing_nice_to_have": []
#     },
#     "2417": {
#       "matched_skills": ["Python", "Java"],
#       "missing_must_have": ["Oracle", "Teradata", "Linux", "shell scripting", "Integration", "XML", "XLST", "WCF", "SOAP", "JSON", "RESTful services", "systems", "application frameworks", "database optimization", "software development projects", "product development", "banking", "trading", "payment", "financial applications", "security", "single sign on", "device fingerprinting", "multi factor authentication", "adaptive authentication", "SDLC methodologies", "Agile", "Rational Unified Process", "deployment automation", "code reviews", "test driven development"],
#       "missing_nice_to_have": []
#     },
#     "9267": {
#       "matched_skills": [],
#       "missing_must_have": ["C#", ".NET", "JavaScript", "object-oriented development", "database management", "scripting"],
#       "missing_nice_to_have": []
#     }
#   }
# }
# Final output:
# # HR Report: Senior Software Engineer Candidate Matching Analysis
#
# ## Executive Summary
#
# This report analyzes the fit between a Senior Software Engineer candidate and three matched job opportunities. The candidate possesses strong Python, CrewAI, and FastAPI skills with 5+ years of experience in AI agents and distributed systems. The analysis reveals varying degrees of alignment across the opportunities, with significant skill gaps identified for two positions.
#
# ## Top Matches Ranked
#
# ### 1. Senior Quality Assurance Engineer (remote/telecommute) - Score: 0.8062
# **Primary Skills Required:** Manual/automated testing, test plans, bug tracking, Selenium, TestNG, Jira, Jenkins/CI, Java, SaaS/On-Premise products
#
# ### 2. Sr. Developer - Python/Java - Score: 0.8038
# **Primary Skills Required:** Python, Java, Oracle/Teradata, Linux, shell scripting, XML, RESTful services, financial applications, SDLC methodologies
#
# ### 3. Software Engineer I-Junior Developer - Score: 0.7984
# **Primary Skills Required:** C#, .NET, JavaScript, object-oriented development, database management
#
# ## Detailed Analysis
#
# ### Position 1: Senior Quality Assurance Engineer
# **Match Score:** 0.8062
#
# **Skill Gaps Identified:**
# - No overlap in required skills
# - Missing 26 critical testing and quality assurance skills
# - No relevant experience in QA methodologies
#
# **Interview Questions:**
# 1. Can you describe your experience with manual and automated testing?
# 2. How do you approach problem-solving and decision-making in your testing process?
# 3. What is your experience with agile development and rapid development cycles?
# 4. Can you explain your experience with tools like Selenium, TestNG, Jira, and Jenkins/CI?
# 5. How do you ensure effective communication in both oral and written forms during testing projects?
#
# **Recommendation:** Low fit. The candidate lacks fundamental QA skills and experience. Consider only if the candidate is willing to transition into a QA role with significant training.
#
# ### Position 2: Sr. Developer - Python/Java
# **Match Score:** 0.8038
#
# **Matched Skills:** Python, Java
#
# **Skill Gaps Identified:**
# - Missing 17 database and integration skills
# - No experience with financial applications or banking domain
# - Limited exposure to enterprise deployment methodologies
#
# **Interview Questions:**
# 1. Can you describe your experience with Python and Java in software development?
# 2. What is your experience with Oracle and Teradata databases?
# 3. Can you explain your familiarity with Linux and shell scripting?
# 4. How do you approach integration and working with XML, XLST, WCF, SOAP, JSON, and RESTful services?
# 5. What is your experience with database optimization and software development projects?
#
# **Recommendation:** Moderate fit. Strong technical foundation in core languages but requires significant domain-specific training. Suitable for candidates interested in financial technology sector.
#
# ### Position 3: Software Engineer I-Junior Developer
# **Match Score:** 0.7984
#
# **Skill Gaps Identified:**
# - No overlap in required skills
# - Missing 6 fundamental development skills
# - Experience level mismatch (senior vs entry-level)
#
# **Interview Questions:**
# 1. Can you describe your experience with C# and .NET development?
# 2. What is your familiarity with JavaScript and object-oriented development?
# 3. How do you approach database management and scripting in your projects?
# 4. Can you clarify your experience with specific database management systems?
# 5. Can you describe a complex project you led using C# and .NET?
#
# **Recommendation:** Low fit. Significant skill gaps and experience level mismatch. Not recommended unless candidate is willing to accept junior-level position.
#
# ## Overall Recommendation
#
# **Best Match:** Sr. Developer - Python/Java position offers the most promising alignment due to shared Python and Java expertise.
#
# **Key Considerations:**
# 1. **Training Investment Required:** All positions require significant upskilling in specific domains
# 2. **Career Transition Potential:** QA position represents a career pivot requiring substantial commitment
# 3. **Domain Expertise Gap:** Financial services position needs banking domain knowledge development
# 4. **Experience Level Alignment:** Candidate is overqualified for junior position
#
# **Suggested Action Plan:**
# 1. Prioritize discussion with Sr. Developer - Python/Java role
# 2. Assess candidate's willingness to learn financial domain concepts
# 3. Evaluate training budget for skill gap closure
# 4. Consider pairing with senior team members for knowledge transfer
#
# **Caveats:**
# - All positions require significant investment in skill development
# - Career trajectory may need adjustment for optimal fit
# - Domain-specific experience cannot be quickly acquired
# - Consider long-term growth potential versus immediate skill gaps
#
# This analysis suggests pursuing the Sr. Developer position while being transparent about required learning curves and development opportunities.
# ╭────────────────────────────────────────────── ✅ Flow Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Flow Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  TalentSelectionFlow                                                                                            │
# │  ID:                                                                                                            │
# │  6a8f7ab5-5d16-46e3-984d-dc0dd7b64f08                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
