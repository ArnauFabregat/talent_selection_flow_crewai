# %%
import sys
sys.path.insert(0, "..")

from src.talent_selection_flow.flow import TalentSelectionFlow

# %%
flow = TalentSelectionFlow(verbose=False)

# %%
cv_example = """
# CURRICULUM VITAE: ALEX R. DEVELOPER

## CONTACT INFORMATION
+ Email: alex.dev@email.com
+ Location: Houston, Texas
+ LinkedIn: linkedin.com/in/alexdev

---

## PROFESSIONAL SUMMARY
Highly analytical Software Engineer with 5+ years of experience in Python 
and AI orchestration. Expert in building multi-agent systems using CrewAI.

---

## EXPERIENCE
+ **Senior Backend Engineer** | TechFlow Solutions (2021 - Present)
  - Led the migration of legacy pipelines to a microservices architecture.
  - Implemented automated CV screening using LLM-based gap analysis.

+ **Junior Developer** | Startup Inc. (2018 - 2021)
  - Developed RESTful APIs using FastAPI and PostgreSQL.
  - Optimized database queries, reducing latency by 30%.

---

## TECHNICAL SKILLS
+ Languages: Python, JavaScript, SQL
+ Frameworks: CrewAI, LangChain, FastAPI, Django
+ Tools: Docker, Kubernetes, Git, OpenRouter API

---

## EDUCATION
+ B.S. in Computer Science | University of Technology
"""
job_example = """
# JOB POSTING: Senior Backend Engineer (AI Systems)

## POSITION OVERVIEW
We are seeking a Senior Backend Engineer to join our AI Orchestration team. 
The ideal candidate will design and maintain scalable microservices that 
power our autonomous agent frameworks.

---

## KEY RESPONSIBILITIES
+ Architect and deploy Python-based microservices using FastAPI.
+ Integrate Large Language Models (LLMs) via OpenRouter and LangChain.
+ Optimize containerized workflows using Docker and Kubernetes.
+ Mentor junior developers and conduct deep-dive code reviews.

---

## TECHNICAL REQUIREMENTS
- **Languages**: Python (Expert), SQL, Bash scripting.
- **Frameworks**: FastAPI, Django, or Flask.
- **Data**: PostgreSQL, Redis, and Vector Databases (Chroma/Pinecone).
- **Infrastructure**: AWS, Docker, Kubernetes, CI/CD pipelines.
- **AI Tools**: Experience with CrewAI or LangChain is a significant plus.

---

## QUALIFICATIONS
+ 5+ years of professional software development experience.
+ Strong understanding of Distributed Systems and Asyncio.
+ Located in or able to work Texas
+ Bachelor's or Master's degree in Computer Science or related field.

---

## BENEFITS
- Competitive salary in the range of 60k - 90k EUR.
- Remote-first culture with flexible working hours.
- Learning budget for AI certifications and conferences.
"""
other_example = "tot el camp és un clam, som la gent blaugrana"

# %%
# await kickoff_async for notebooks
response = await flow.kickoff_async(inputs={"raw_input": job_example})
