# %%
import sys
sys.path.insert(0, "..")

from src.talent_selection_flow.flow import TalentSelectionFlow

# %%
flow = TalentSelectionFlow(verbose=False)

# %%
cv_example = """
# CURRICULUM VITAE: ALEX R. DEVELOPER

## CONTACT INFORMATION
+ Email: alex.dev@email.com
+ Location: Houston, Texas
+ LinkedIn: linkedin.com/in/alexdev

---

## PROFESSIONAL SUMMARY
Highly analytical Software Engineer with 5+ years of experience in Python 
and AI orchestration. Expert in building multi-agent systems using CrewAI.

---

## EXPERIENCE
+ **Senior Backend Engineer** | TechFlow Solutions (2021 - Present)
  - Led the migration of legacy pipelines to a microservices architecture.
  - Implemented automated CV screening using LLM-based gap analysis.

+ **Junior Developer** | Startup Inc. (2018 - 2021)
  - Developed RESTful APIs using FastAPI and PostgreSQL.
  - Optimized database queries, reducing latency by 30%.

---

## TECHNICAL SKILLS
+ Languages: Python, JavaScript, SQL
+ Frameworks: CrewAI, LangChain, FastAPI, Django
+ Tools: Docker, Kubernetes, Git, OpenRouter API

---

## EDUCATION
+ B.S. in Computer Science | University of Technology
"""
job_example = "We are seeking a Senior Data Scientist to lead our LLM optimization team. Requirements include 4+ years of experience with PyTorch, LangChain, and vector databases. You will be responsible for fine-tuning models and improving retrieval-augmented generation (RAG) pipelines in a fast-paced startup environment."
other_example = "tot el camp és un clam, som la gent blaugrana"

# %%
# await kickoff_async for notebooks
response = await flow.kickoff_async(inputs={"raw_input": cv_example})
# Out:
# Flow started with ID: 5d94e241-e05c-4aec-be6c-22ec4fc0230d
# ╭─────────────────────────────────────────────── 🌊 Flow Execution ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name:                                                                                                          │
# │  TalentSelectionFlow                                                                                            │
# │  ID:                                                                                                            │
# │  5d94e241-e05c-4aec-be6c-22ec4fc0230d                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────── 🔄 Flow Method Running ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Method: classify_input                                                                                         │
# │  Status: Running                                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 🌊 Flow Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Flow Started                                                                                                   │
# │  Name: TalentSelectionFlow                                                                                      │
# │  ID: 5d94e241-e05c-4aec-be6c-22ec4fc0230d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2026-02-16 16:23:11.075 | DEBUG    | src.talent_selection_flow.crews.classification_crew.guardrails:validate_classifier_output:10 - Guardrail input: 'cv'
# 2026-02-16 16:23:13.903 | DEBUG    | src.db_ingestion.metadata_extraction_crew.guardrails:validate_cvmetadata_schema:12 - Guardrail input:
# {"skills": "Python, JavaScript, SQL, CrewAI, LangChain, FastAPI, Django, Docker, Kubernetes, Git, OpenRouter API", "industries": "Software Development, AI, Tech", "experience_level": "senior", "country": "US", "summary": "Highly analytical Software Engineer with 5+ years of experience in Python and AI orchestration. Expert in building multi-agent systems using CrewAI.", "education_level": "bachelor", "languages": "unknown"}
# 2026-02-16 16:23:14.386 | INFO     | src.db_ingestion.chroma_client:query_to_collection:153 - Initiating vector search in collection 'jobs' (Top K: 3)
# 2026-02-16 16:23:21.537 | DEBUG    | src.db_ingestion.chroma_client:query_to_collection:175 - Final formatted results:
# {'9267': {'title': 'Software Engineer I-Junior Developer', 'similarity': 0.8744000000000001, 'skills': 'C#, .NET, JavaScript, object-oriented development, database management, scripting', 'industries': 'Computer Software', 'experience_level': 'entry', 'summary': "Join an established team and grow your development skills while providing valuable contributions to our client's higher education commercial software solutions and their customers.", 'country': 'US'}, '16162': {'title': 'Senior Quality Assurance Engineer (remote/telecommute)', 'similarity': 0.8516, 'skills': 'manual and automated testing, test plans, bug tracking, problem solving, decision-making, software engineering fundamentals, unit testing, automated testing, white-box and black-box testing, agile development, Selenium, TestNG, rapid development cycles, Jira, Testrail, Jenkins/CI, Git, HTML5/CSS/JavaScript, Java, Continuous Integration/Continuous Delivery, SaaS, On-Premise Enterprise products, Windows, OSX, iOS, Android, oral and written communications', 'industries': 'Internet', 'experience_level': 'senior', 'summary': 'Participate in product development process and ensure optimum quality of application by planning, scheduling and executing manual and automated testing throughout the development cycle and during periodic releases.', 'country': 'US'}, '2417': {'title': 'Sr. Developer - Python/Java', 'similarity': 0.8482000000000001, 'skills': 'Python, Oracle, Teradata, Linux, Java, shell scripting, Integration, XML, XLST, WCF, SOAP, JSON, RESTful services, systems, application frameworks, database optimization, software development projects, product development, banking, trading, payment, financial applications, security, single sign on, device fingerprinting, multi factor authentication, adaptive authentication, SDLC methodologies, Agile, Rational Unified Process, deployment automation, code reviews, test driven development', 'industries': 'Banking', 'experience_level': 'senior', 'summary': 'Leading bank is seeking a Senior Software Engineer (Python/ Java) in San Ramon for a contract role. The client is seeking a senior software engineer contractor for the Shared Services team.', 'country': 'US'}}
# 2026-02-16 16:23:33.832 | DEBUG    | src.talent_selection_flow.crews.cv_to_job_crew.guardrails:validate_gapanalysisoutput_schema:11 - Guardrail input:
# {
#   "jobs": {
#     "9267": {
#       "matched_skills": [
#         "JavaScript"
#       ],
#       "missing_must_have": [
#         "C#",
#         ".NET",
#         "object-oriented development",
#         "database management",
#         "scripting"
#       ]
#     },
#     "16162": {
#       "matched_skills": [
#         "JavaScript",
#         "Git"
#       ],
#       "missing_must_have": [
#         "manual and automated testing",
#         "test plans",
#         "bug tracking",
#         "problem solving",
#         "decision-making",
#         "software engineering fundamentals",
#         "unit testing",
#         "automated testing",
#         "white-box and black-box testing",
#         "agile development",
#         "Selenium",
#         "TestNG",
#         "rapid development cycles",
#         "Jira",
#         "Testrail",
#         "Jenkins/CI",
#         "HTML5/CSS",
#         "Java",
#         "Continuous Integration/Continuous Delivery",
#         "SaaS",
#         "On-Premise Enterprise products",
#         "Windows",
#         "OSX",
#         "iOS",
#         "Android",
#         "oral and written communications"
#       ]
#     },
#     "2417": {
#       "matched_skills": [
#         "Python",
#         "Java",
#         "XML",
#         "JSON",
#         "RESTful services",
#         "Linux"
#       ],
#       "missing_must_have": [
#         "Oracle",
#         "Teradata",
#         "shell scripting",
#         "Integration",
#         "XLST",
#         "WCF",
#         "SOAP",
#         "systems",
#         "application frameworks",
#         "database optimization",
#         "software development projects",
#         "product development",
#         "banking",
#         "trading",
#         "payment",
#         "financial applications",
#         "security",
#         "single sign on",
#         "device fingerprinting",
#         "multi factor authentication",
#         "adaptive authentication",
#         "SDLC methodologies",
#         "Agile",
#         "Rational Unified Process",
#         "deployment automation",
#         "code reviews",
#         "test driven development"
#       ]
#     }
#   }
# }
# 2026-02-16 16:23:58.576 | DEBUG    | src.talent_selection_flow.crews.cv_to_job_crew.guardrails:validate_interviewquestionsoutput_schema:48 - Guardrail input:
# {
#   "jobs": {
#     "9267": {
#       "matched_skill_questions": [
#         {"question": "Can you describe a project where you used JavaScript extensively?", "response": "I developed a web application using JavaScript for dynamic user interactions and data manipulation."},
#         {"question": "What are some key features of JavaScript that you find most useful?", "response": "JavaScript's event-driven nature and its ability to manipulate the DOM make it very powerful for creating interactive web applications."}
#       ],
#       "gap_probing_questions": [
#         {"question": "Have you worked with C# or .NET in any of your projects?", "response": "I have not worked with C# or .NET, but I am familiar with object-oriented programming concepts."},
#         {"question": "Can you explain your experience with database management?", "response": "I have basic knowledge of database management but have not worked extensively with it."},
#         {"question": "How do you approach object-oriented development?", "response": "I understand the principles of object-oriented development but have not applied them in a professional setting."}
#       ],
#       "ambiguity_clarification_questions": [
#         {"question": "What level of experience do you have with scripting languages?", "response": "I have experience with JavaScript and some basic scripting in Python."}
#       ],
#       "seniority_questions": [
#         {"question": "How do you handle complex software development tasks?", "response": "I break down complex tasks into smaller, manageable parts and use version control to track changes."},
#         {"question": "Can you describe a time when you had to learn a new technology quickly?", "response": "I recently learned React.js for a project, dedicating time to tutorials and practice to become proficient."}
#       ]
#     },
#     "16162": {
#       "matched_skill_questions": [
#         {"question": "Can you describe a project where you used JavaScript and Git?", "response": "I developed a web application using JavaScript for the frontend and Git for version control."},
#         {"question": "How do you ensure code quality in your projects?", "response": "I use Git for version control and follow coding standards to maintain code quality."}
#       ],
#       "gap_probing_questions": [
#         {"question": "What is your experience with manual and automated testing?", "response": "I have basic knowledge of testing but have not worked extensively with automated testing tools."},
#         {"question": "Can you explain your experience with agile development?", "response": "I have worked in agile teams but have not led agile projects."},
#         {"question": "How do you handle bug tracking and test plans?", "response": "I use basic bug tracking but have not created comprehensive test plans."}
#       ],
#       "ambiguity_clarification_questions": [
#         {"question": "What is your experience with SaaS and On-Premise Enterprise products?", "response": "I have worked with SaaS products but have limited experience with On-Premise Enterprise solutions."}
#       ],
#       "seniority_questions": [
#         {"question": "How do you approach problem-solving in software development?", "response": "I analyze the problem, research solutions, and implement the most efficient one."},
#         {"question": "Can you describe a time when you had to make a critical decision in a project?", "response": "I had to decide on a technology stack for a project, considering factors like scalability and team expertise."}
#       ]
#     },
#     "2417": {
#       "matched_skill_questions": [
#         {"question": "Can you describe a project where you used Python, Java, and RESTful services?", "response": "I developed a backend service using Python and Java, integrating RESTful APIs for data exchange."},
#         {"question": "How do you handle XML and JSON data in your projects?", "response": "I parse and manipulate XML and JSON data using libraries like Jackson and Gson in Java."}
#       ],
#       "gap_probing_questions": [
#         {"question": "What is your experience with Oracle and Teradata databases?", "response": "I have basic knowledge of databases but have not worked with Oracle or Teradata specifically."},
#         {"question": "Can you explain your experience with shell scripting?", "response": "I have basic knowledge of shell scripting but have not used it extensively in projects."},
#         {"question": "How do you approach database optimization?", "response": "I understand the importance of indexing and query optimization but have not implemented them in a professional setting."}
#       ],
#       "ambiguity_clarification_questions": [
#         {"question": "What is your experience with security and authentication methods?", "response": "I have basic knowledge of security concepts but have not implemented advanced authentication methods."}
#       ],
#       "seniority_questions": [
#         {"question": "How do you handle deployment automation and code reviews?", "response": "I use CI/CD tools for deployment automation and participate in code reviews to ensure quality."},
#         {"question": "Can you describe a time when you had to adapt to a new development methodology?", "response": "I transitioned from waterfall to agile development, adapting to iterative development cycles."}
#       ]
#     }
#   }
# }
# ╭────────────────────────────────────────────── ✅ Flow Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Flow Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  TalentSelectionFlow                                                                                            │
# │  ID:                                                                                                            │
# │  5d94e241-e05c-4aec-be6c-22ec4fc0230d                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
